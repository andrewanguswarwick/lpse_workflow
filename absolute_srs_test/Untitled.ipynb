# %%
import write_files as wf
import ihp
import lpse_data as ld
import matplotlib.pyplot as plt
import numpy as np
from time import time as stopwatch
from calc_inputs import *

# Ipython magic features
# %load_ext autoreload
# %autoreload 2
  
# LPSE class
lpse = ld.lpse_case()
lpse.dfp = './data/lpse.' # Data file prefix
lpse.verbose = False # Show prints
lpse.np = 1 # Number of processors
lpse.bin = '/home/space/phrfqm/lpse-3.2.11/bin/lpse_cpu' # Binary
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
io = wf.io_control()
io.grid.downSampleFactors = 1 # Spatial
io.laser.save.E0.z = lpse.dfp + 'E0_z'
io.raman.save.E0.z = lpse.dfp + 'E1_z'
io.lw.save.pots = lpse.dfp + 'pots'
#io.laser.save.S0.x = lpse.dfp + 'S0_x'
io.raman.save.S0.x = lpse.dfp + 'S1_x'
lpse.add_class(io)

# %%
lpse.run()

# %%
lpse.fields()
# Out:
# ./data/lpse.pots
# ./data/lpse.E0_z
# ./data/lpse.E1_z
# ./data/lpse.S1_x

# %%
lpse.plot_field('E0_z')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-6fdefa6a03e0> in <module>
# ----> 1 lpse.plot_field('E0_z')
#
# ~/lpse-3.2.11/cases/lpse_utils/lpse_data.py in plot_field(self, ky)
#     252     axcolor = 'lightgoldenrodyellow'
#     253     axtime = plt.axes([0.10, 0.05, 0.8, 0.03], facecolor=axcolor)
# --> 254     delta_t = tdat[1]-tdat[0]
#     255     stime = Slider(axtime, 'Time', tdat[0], tdat[-1], valinit=tdat[0], valstep=delta_t)
#     256
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
# %matplotlib notebook
lpse.plot_field('E1_z')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-570ccc13309e> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 lpse.plot_field('E1_z')
#
# ~/lpse-3.2.11/cases/lpse_utils/lpse_data.py in plot_field(self, ky)
#     252     axcolor = 'lightgoldenrodyellow'
#     253     axtime = plt.axes([0.10, 0.05, 0.8, 0.03], facecolor=axcolor)
# --> 254     delta_t = tdat[1]-tdat[0]
#     255     stime = Slider(axtime, 'Time', tdat[0], tdat[-1], valinit=tdat[0], valstep=delta_t)
#     256
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
